# %% [markdown]
# <a href="https://colab.research.google.com/github/BERGzie/unemployed_indian_DataModel/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import logging
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
import joblib

# Setup logging
logging.basicConfig(level=logging.INFO, format='%(levelname)s: %(message)s')

def load_and_prepare_data(filepath):
    logging.info("Loading dataset...")
    df = pd.read_csv(filepath)

    # Drop rows with missing values
    df.dropna(inplace=True)
    logging.info(f"Data shape after dropping NAs: {df.shape}")

    # --- Create a dummy target column ---
    # Example logic: if Age < 30 and no experience → more likely unemployed
    df['Target'] = ((df['Age'] < 30) & (df['Previous Experience'] == 0)).astype(int)

    # Encode categorical columns (e.g., Name, Degree)
    for col in df.select_dtypes(include='object').columns:
        df[col] = LabelEncoder().fit_transform(df[col])
        logging.info(f"Encoded column: {col}")

    # Separate features and target
    X = df.drop('Target', axis=1)
    y = df['Target']

    # Scale features
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)

    # Save scaler for production use
    joblib.dump(scaler, 'scaler.pkl')

    # Train-test split
    return train_test_split(X_scaled, y, test_size=0.2, random_state=42)

def build_model(input_dim):
    model = Sequential([
        Dense(128, activation='relu', input_dim=input_dim),
        Dropout(0.3),
        Dense(64, activation='relu'),
        Dropout(0.3),
        Dense(1, activation='sigmoid')  # For binary classification
    ])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

def run_training(X_train, X_test, y_train, y_test):
    model = build_model(X_train.shape[1])
    logging.info("Training the model...")

    early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

    model.fit(
        X_train, y_train,
        validation_data=(X_test, y_test),
        epochs=50,
        batch_size=32,
        callbacks=[early_stop],
        verbose=1
    )

    # Save model
    model.save("unemployment_model.h5")
    logging.info("Model saved as 'unemployment_model.h5'")

    # Evaluate
    loss, accuracy = model.evaluate(X_test, y_test)
    logging.info(f"Test Accuracy: {accuracy:.4f}")

if __name__ == "__main__":
    filepath = "unemployed_indian_dataset.csv"
    X_train, X_test, y_train, y_test = load_and_prepare_data(filepath)
    run_training(X_train, X_test, y_train, y_test)
# Out:
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9358 - loss: 0.4637 - val_accuracy: 1.0000 - val_loss: 0.1322
# Epoch 2/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 0.0924 - val_accuracy: 1.0000 - val_loss: 0.0244
# Epoch 3/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0192 - val_accuracy: 1.0000 - val_loss: 0.0091
# Epoch 4/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0087 - val_accuracy: 1.0000 - val_loss: 0.0049
# Epoch 5/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0049 - val_accuracy: 1.0000 - val_loss: 0.0031
# Epoch 6/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 1.0000 - val_loss: 0.0021
# Epoch 7/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 1.0000 - val_loss: 0.0015
# Epoch 8/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 1.0000 - val_loss: 0.0011
# Epoch 9/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 8.7873e-04
# Epoch 10/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 9.4357e-04 - val_accuracy: 1.0000 - val_loss: 7.0317e-04
# Epoch 11/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 8.8295e-04 - val_accuracy: 1.0000 - val_loss: 5.6446e-04
# Epoch 12/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 6.5550e-04 - val_accuracy: 1.0000 - val_loss: 4.7110e-04
# Epoch 13/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 5.2546e-04 - val_accuracy: 1.0000 - val_loss: 4.0235e-04
# Epoch 14/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 5.5544e-04 - val_accuracy: 1.0000 - val_loss: 3.4516e-04
# Epoch 15/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 3.4971e-04 - val_accuracy: 1.0000 - val_loss: 3.0000e-04
# Epoch 16/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 3.9077e-04 - val_accuracy: 1.0000 - val_loss: 2.5903e-04
# Epoch 17/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 3.5029e-04 - val_accuracy: 1.0000 - val_loss: 2.2716e-04
# Epoch 18/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 3.0966e-04 - val_accuracy: 1.0000 - val_loss: 2.0092e-04
# Epoch 19/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 2.9099e-04 - val_accuracy: 1.0000 - val_loss: 1.7948e-04
# Epoch 20/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 2.1314e-04 - val_accuracy: 1.0000 - val_loss: 1.6097e-04
# Epoch 21/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 2.5300e-04 - val_accuracy: 1.0000 - val_loss: 1.4416e-04
# Epoch 22/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 1.8420e-04 - val_accuracy: 1.0000 - val_loss: 1.2994e-04
# Epoch 23/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 2.4860e-04 - val_accuracy: 1.0000 - val_loss: 1.1666e-04
# Epoch 24/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 2.6160e-04 - val_accuracy: 1.0000 - val_loss: 1.0599e-04
# Epoch 25/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 1.5038e-04 - val_accuracy: 1.0000 - val_loss: 9.6330e-05
# Epoch 26/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 1.4066e-04 - val_accuracy: 1.0000 - val_loss: 8.8072e-05
# Epoch 27/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 1.3579e-04 - val_accuracy: 1.0000 - val_loss: 8.0766e-05
# Epoch 28/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 1.1191e-04 - val_accuracy: 1.0000 - val_loss: 7.4305e-05
# Epoch 29/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 1.3742e-04 - val_accuracy: 1.0000 - val_loss: 6.8342e-05
# Epoch 30/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 1.3853e-04 - val_accuracy: 1.0000 - val_loss: 6.2859e-05
# Epoch 31/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 1.1781e-04 - val_accuracy: 1.0000 - val_loss: 5.7366e-05
# Epoch 32/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 9.7992e-05 - val_accuracy: 1.0000 - val_loss: 5.3094e-05
# Epoch 33/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 7.6045e-05 - val_accuracy: 1.0000 - val_loss: 4.9847e-05
# Epoch 34/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 7.1299e-05 - val_accuracy: 1.0000 - val_loss: 4.6484e-05
# Epoch 35/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 7.1532e-05 - val_accuracy: 1.0000 - val_loss: 4.3679e-05
# Epoch 36/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 5.9893e-05 - val_accuracy: 1.0000 - val_loss: 4.1158e-05
# Epoch 37/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 1.0420e-04 - val_accuracy: 1.0000 - val_loss: 3.8145e-05
# Epoch 38/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 8.4059e-05 - val_accuracy: 1.0000 - val_loss: 3.5790e-05
# Epoch 39/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 6.2021e-05 - val_accuracy: 1.0000 - val_loss: 3.3694e-05
# Epoch 40/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 7.9518e-05 - val_accuracy: 1.0000 - val_loss: 3.1564e-05
# Epoch 41/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 6.0028e-05 - val_accuracy: 1.0000 - val_loss: 2.9792e-05
# Epoch 42/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 4.8503e-05 - val_accuracy: 1.0000 - val_loss: 2.8322e-05
# Epoch 43/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 5.4104e-05 - val_accuracy: 1.0000 - val_loss: 2.6891e-05
# Epoch 44/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 4.0987e-05 - val_accuracy: 1.0000 - val_loss: 2.5580e-05
# Epoch 45/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 6.3912e-05 - val_accuracy: 1.0000 - val_loss: 2.4108e-05
# Epoch 46/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 5.4647e-05 - val_accuracy: 1.0000 - val_loss: 2.2979e-05
# Epoch 47/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 5.5076e-05 - val_accuracy: 1.0000 - val_loss: 2.1816e-05
# Epoch 48/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 4.7743e-05 - val_accuracy: 1.0000 - val_loss: 2.0740e-05
# Epoch 49/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 3.7552e-05 - val_accuracy: 1.0000 - val_loss: 1.9698e-05
# Epoch 50/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 5.3041e-05 - val_accuracy: 1.0000 - val_loss: 1.8669e-05
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 2.2979e-05
